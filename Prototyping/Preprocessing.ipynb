# %% [markdown]
# # Preprocessing Notebook

# %% [markdown]
# ## Installs

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %% [markdown]
# ## Imports

# %%
from google.colab import drive
import pandas as pd
import spacy
import regex as re
import nltk
from nltk.corpus import stopwords
from tqdm.notebook import tqdm
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# # Preprocessing of email text

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
file = open('/content/drive/MyDrive/Mails.csv',mode='r', encoding='utf-8')
lines = file.read().split('!#ENDOFLINE#!')
file.close()

# Split the data
for i in range(len(lines)):
    lines[i] = lines[i].split('!#!')
    for j in range(len(lines[i])):
        lines[i][j] = lines[i][j].strip()
        
# Load it to a data frame
df = pd.DataFrame(lines)
df.columns = df.iloc[0]
df = df[1:]

# Small bugfix (work around)
df = df.rename(columns={"﻿Subject" : "Subject"})

# %%
nlp = spacy.load('en_core_web_sm')
COLUMN = ['Body']
#symbols = re.compile('[/(){}\[\]\|@,;:]')
#symbols = ['<', '>', '|', ':', '/', '(', ')', '[', ']', ',', '.', '\\', ' ', '_', '-', '\'', '\"', '!', '?', ';', '&']
STOPWORDS = set(stopwords.words('english'))

df["Body_processed"] = ""


def prepare(data_frame):
    for index, row in tqdm(data_frame.iterrows(), total=data_frame.shape[0]):
        for x in COLUMN:
            if not pd.isnull(data_frame[x][index]):
                # Add title to body
                text = row['Subject'] + " " + row["SenderName"] + " " + row["CCAddresses"] + " " + row['Body']
                # Lemmatize
                doc = nlp(text)
                result = []
                for token in doc:
                    str_token = str(token)
                    if not (str_token.startswith("http://") or str_token.startswith("https://") or len(str_token.strip()) <= 1 or '\\n' in str_token or '\n' in str_token):
                        lemma = token.lemma_.lower()
                        if not lemma in STOPWORDS:
                            result.append(lemma)
                
                result.append(row["SenderAddress"])
                data_frame['Body_processed'][index] = result
    return data_frame
   
df = prepare(df)
df.to_csv('/content/drive/MyDrive/Mails_prepared.csv')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1080.0), HTML(value='')))

# %%
df["Body_processed"][10]
# Out:
# ['um',
#  'news',
#  'maastricht',
#  'university',
#  '13',
#  '04',
#  '2021',
#  'view',
#  'public',
#  'xstllld5h1vw58u8jukjfa',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'email',
#  'browser',
#  'maastricht',
#  'university',
#  'um',
#  'news',
#  'student',
#  'edition',
#  'general',
#  'announcement',
#  'please',
#  'allow',
#  'go',
#  'back',
#  'university',
#  'sender',
#  'marketing',
#  'communications',
#  'mailto:theo.tamis@maastrichtuniversity.nl',
#  'rector',
#  'rianne',
#  'letschert',
#  'recognise',
#  'student',
#  'need',
#  'everything',
#  'power',
#  'open',
#  'university',
#  'september',
#  'much',
#  'possible',
#  'speak',
#  'final',
#  'leg',
#  'faculty',
#  'tour',
#  'tutor',
#  'student',
#  'law',
#  'say',
#  'appreciate',
#  'opportunity',
#  'talk',
#  'rianne',
#  'learn',
#  'faculty',
#  'face',
#  'similar',
#  'issue',
#  'new',
#  'normal',
#  'watch',
#  'video',
#  'public',
#  'r/3qm1us_athmuyljhwlwm0w',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'umcard',
#  'payment',
#  'temporarily',
#  'order',
#  'tomorrow',
#  '6:00',
#  'pm',
#  'sender',
#  'facility',
#  'services',
#  'mailto:servicepoint-fs@maastrichtuniversity.nl',
#  'umcard',
#  'payment',
#  'temporarily',
#  'order',
#  'tomorrow',
#  '6:00',
#  'pm',
#  'temporarily',
#  'possible',
#  'pay',
#  'umcard',
#  'wednesday',
#  '14',
#  'april',
#  '2021',
#  '6:00',
#  'pm',
#  'system',
#  'offline',
#  'maximum',
#  'hour',
#  'due',
#  'maintenance',
#  'time',
#  'period',
#  'still',
#  'use',
#  'umcard',
#  'gain',
#  'access',
#  'building',
#  'library',
#  'read',
#  'student',
#  'panel',
#  'sender',
#  'student',
#  'project',
#  'team',
#  'mailto:l.somogyvari@maastrichtuniversity.nl',
#  'student',
#  'panel',
#  'would',
#  'like',
#  'great',
#  'influence',
#  'within',
#  'university',
#  'ever',
#  'notice',
#  'aspect',
#  'um',
#  'operation',
#  'could',
#  'improve',
#  'answer',
#  'yes',
#  'student',
#  'panel',
#  'place',
#  'read',
#  'lose',
#  'legal',
#  'regulation',
#  'relate',
#  'study',
#  'ask',
#  'student',
#  'dean',
#  'sender',
#  'studentendecanen',
#  'mailto:studentendecanen@maastrichtuniversity.nl',
#  'lose',
#  'legal',
#  'regulation',
#  'relate',
#  'study',
#  'ask',
#  'student',
#  'dean',
#  'explain',
#  'situation',
#  'ask',
#  'question',
#  'student',
#  'dean',
#  'email',
#  'also',
#  'schedule',
#  'online',
#  'appointment',
#  'click',
#  'public',
#  'sovwqycqipf2d5fv6cj5tg',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'contact',
#  'detail',
#  'student',
#  'accommodation',
#  'sorbonnelaan',
#  'sender',
#  'huurteam',
#  'zuidlimburg',
#  'mailto:info@huurteam-zuidlimburg.nl',
#  'student',
#  'accommodation',
#  'sorbonnelaan',
#  'huurteam',
#  'receive',
#  'many',
#  'complaint',
#  'student',
#  'rent',
#  'accommodation',
#  'sorbonnelaan',
#  'manage',
#  'camelot',
#  'think',
#  'pay',
#  'much',
#  'rent',
#  'service',
#  'cost',
#  'want',
#  'something',
#  'together',
#  'contact',
#  'free',
#  'advice',
#  'assistance',
#  'read',
#  'make',
#  'voice',
#  'hear',
#  'sender',
#  'central',
#  'elections',
#  'office',
#  'um',
#  'mailto:verkiezingen@maastrichtuniversity.nl',
#  'election',
#  'faculty',
#  'councils',
#  'university',
#  'council',
#  'take',
#  'place',
#  '17',
#  '20',
#  'may.',
#  'want',
#  'able',
#  'participate',
#  'discussion',
#  'advise',
#  'important',
#  'matter',
#  'field',
#  'education',
#  'personnel',
#  'matter',
#  'faculty',
#  'entire',
#  'university',
#  'please',
#  'submit',
#  'candidacy',
#  '15',
#  'april',
#  'via',
#  'website',
#  'public',
#  'azowty_6a0t1rzxq06f8hg',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'get',
#  'active',
#  'spring',
#  'um',
#  'step',
#  'challenge',
#  'start',
#  'thursday',
#  'sender',
#  'arbo',
#  'hr',
#  'mailto:k.jacobs@maastrichtuniversity.nl',
#  'thursday',
#  '15',
#  'april',
#  '1100',
#  'participant',
#  'start',
#  'um',
#  'step',
#  'challenge',
#  'challenge',
#  'faculty',
#  'service',
#  'centre',
#  'compete',
#  'title',
#  'active',
#  'faculty',
#  'service',
#  'centre',
#  'um',
#  'sum',
#  'money',
#  'vitality',
#  'promotion',
#  'video',
#  'public',
#  'jsrhxdd6kmu4o5gtg16dug',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'prof',
#  'stef',
#  'kremers',
#  'professor',
#  'health',
#  'promotion',
#  'share',
#  'tip',
#  'get',
#  'exercise',
#  'daily',
#  'routine',
#  'read',
#  'subscribe',
#  'observant',
#  'newsletter',
#  'sender',
#  'observant',
#  'mailto:cleo.freriks@maastrichtuniversity.nl',
#  'student',
#  'organisation',
#  'try',
#  'keep',
#  'people',
#  "'s",
#  'interest',
#  'online',
#  'activity',
#  'action',
#  'group',
#  'wo',
#  'actie',
#  'call',
#  'attention',
#  'plight',
#  'high',
#  'education',
#  'american',
#  'maastricht',
#  'pandemic',
#  'observant',
#  'newsletter',
#  'public',
#  'rfypulzc5sngk1a1ho7qfa',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'want',
#  'read',
#  'subscribe',
#  'public',
#  'grmtffphg4b1tzjlpprf0w',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'seminars',
#  'symposia',
#  'lecture',
#  'online',
#  'programme',
#  'studium',
#  'generale',
#  'sender',
#  'studium',
#  'generale',
#  'mailto:ties.vandijk@maastrichtuniversity.nl',
#  'online',
#  'programme',
#  'studium',
#  'generale',
#  'mo',
#  '19',
#  'apr',
#  'explore',
#  'field',
#  'forensic',
#  'pathology',
#  'public',
#  'b01hjbkolrktsirrwz0r0a',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'lecture',
#  '21',
#  'apr',
#  'let',
#  '’s',
#  'talk',
#  'engagement',
#  'future',
#  'public',
#  'ifes1xqoc9fazyiqvbrtlg',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'lecture',
#  'mo',
#  '10',
#  'may',
#  'europe',
#  'pandemic',
#  'public',
#  'r/6sfhnmavhorus_alxx9+tq',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'lecture',
#  'information',
#  'registration',
#  'website',
#  'public',
#  'xcj2mi+yz0xjiaux7yjeba',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'data',
#  'science',
#  'research',
#  'seminar',
#  'series',
#  'sender',
#  'bernice',
#  'breuer',
#  'mailto:b.breuer@maastrichtuniversity.nl',
#  'data',
#  'science',
#  'research',
#  'seminar',
#  'series',
#  'thursday',
#  '15',
#  'april',
#  '2021',
#  '12:00',
#  '13:00',
#  'data',
#  'science',
#  'research',
#  'seminar',
#  'organise',
#  'behalf',
#  'institute',
#  'data',
#  'science',
#  'ids',
#  'seminar',
#  'organise',
#  'collaboration',
#  'department',
#  'data',
#  'science',
#  'knowledge',
#  'engineering',
#  'dke',
#  'speaker',
#  'nava',
#  'tintarev',
#  'joël',
#  'karel',
#  'read',
#  'maastricht',
#  'young',
#  'academy',
#  'organise',
#  'seventh',
#  'gus',
#  'event',
#  'um',
#  'sender',
#  'maastricht',
#  'young',
#  'academy',
#  'mailto:j.rowlands@student.maastrichtuniversity.nl',
#  'session',
#  'take',
#  'place',
#  'may',
#  '2021',
#  '16h-17h',
#  'dr.',
#  'daniela',
#  'trani',
#  'manage',
#  'director',
#  'young',
#  'universities',
#  'future',
#  'europe',
#  'yufe',
#  'public',
#  'lqjnjpym63xfrf_1onk_qa',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'alliance',
#  'share',
#  'unofficial',
#  'story',
#  'read',
#  'lecture',
#  'future',
#  'paris',
#  'agreement',
#  'sender',
#  'eva',
#  'durlinger',
#  'mailto:e.durlinger@maastrichtuniversity.nl',
#  'lecture',
#  'future',
#  'paris',
#  'agreement',
#  'niclas',
#  'svenningsen',
#  'manager',
#  'global',
#  'climate',
#  'action',
#  'unfccc',
#  'give',
#  'lecture',
#  'title',
#  'future',
#  'unfccc',
#  'make',
#  'paris',
#  'agreement',
#  'ambitious',
#  'friday',
#  '23',
#  'april',
#  '15.00',
#  '16.30',
#  'via',
#  'zoom',
#  'sign',
#  'send',
#  'email<mailto:n.mayer@maastrichtuniversity.nl',
#  'n.',
#  'mayer',
#  'read',
#  'simply',
#  'listen',
#  'professional',
#  'storyteller',
#  'sometimes',
#  'enough',
#  'sender',
#  'innbetween',
#  'mailto:pr-innbetween@maastrichtuniversity.nl',
#  'simply',
#  'listen',
#  'professional',
#  'storyteller',
#  'sometimes',
#  'enough',
#  'join',
#  'cozy',
#  'night',
#  'full',
#  'storytelle',
#  '14',
#  'april',
#  'story',
#  'tell',
#  'ancient',
#  'tradition',
#  'weaving',
#  'offer',
#  'opportunity',
#  'create',
#  'weave',
#  'art',
#  'natural',
#  'material',
#  'yet',
#  'present',
#  'listen',
#  'story',
#  'much',
#  'possible',
#  'information',
#  'registration',
#  'website',
#  'public',
#  'r/4ircaqnr_uymw2lcnjsaaq',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'upcoming',
#  'course',
#  'um',
#  'wellbeing',
#  'movement',
#  'present',
#  'wellbeing',
#  'wednesday',
#  'study',
#  'skills',
#  'sender',
#  'um',
#  'wellbeing',
#  'movement',
#  'mailto:wellbeingmovement@maastrichtuniversity.nl',
#  'um',
#  'wellbeing',
#  'movement',
#  'present',
#  'wellbeing',
#  'wednesday',
#  'study',
#  'skills',
#  'want',
#  'improve',
#  'study',
#  'skill',
#  'struggle',
#  'manage',
#  'time',
#  'whether',
#  'online',
#  'person',
#  'study',
#  'skill',
#  'time',
#  'management',
#  'work',
#  'life',
#  'balance',
#  'crucial',
#  'get',
#  'class',
#  'join',
#  'wellbeing',
#  'wednesday',
#  'study',
#  'skills',
#  '21',
#  'april',
#  'register',
#  'via',
#  'link',
#  'public',
#  'ftwta15ki6sgt5azzhxi1a',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'discover',
#  'online',
#  'law',
#  'politics',
#  'course',
#  'sender',
#  'maastricht',
#  'summer',
#  'school',
#  'mailto:summerschool@maastrichtuniversity.nl',
#  'deepen',
#  'knowledge',
#  'human',
#  'trafficking',
#  'sexual',
#  'violence',
#  'trace',
#  'century',
#  'old',
#  'concept',
#  'global',
#  'great',
#  'powers',
#  'examine',
#  'main',
#  'concept',
#  'international',
#  'relation',
#  'learn',
#  'understand',
#  'world',
#  'politic',
#  'research',
#  'social',
#  'policy',
#  'characteristic',
#  'european',
#  'welfare',
#  'state',
#  'online',
#  'law',
#  'politics',
#  'course',
#  'summer',
#  'information',
#  'registration',
#  'website',
#  'public',
#  'r/6u2yqrx_fix4qp3moljghg',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'get',
#  'science',
#  'online',
#  'summer',
#  'course',
#  'sender',
#  'maastricht',
#  'summer',
#  'school',
#  'mailto:summerschool@maastrichtuniversity.nl',
#  'get',
#  'science',
#  'online',
#  'summer',
#  'course',
#  'online',
#  'science',
#  'course',
#  'cover',
#  'wide',
#  'range',
#  'topic',
#  'consumer',
#  'neuroscience',
#  'datum',
#  'science',
#  'psychology',
#  'medical',
#  'ethic',
#  'relationship',
#  'science',
#  'religion',
#  'europe',
#  'please',
#  'refer',
#  'website',
#  'public',
#  'krf_uk6bhk+ie1ld7ffd1a',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'information',
#  'course',
#  'submit',
#  'application',
#  'join',
#  'online',
#  'language',
#  'cafe',
#  'sender',
#  'language',
#  'centre',
#  'mailto:m.vanwell@maastrichtuniversity.nl',
#  'join',
#  'online',
#  'language',
#  'cafe',
#  'would',
#  'like',
#  'practise',
#  'dutch',
#  'together',
#  'people',
#  'already',
#  'minimum',
#  'a2',
#  'level',
#  'high',
#  'join',
#  'enjoyable',
#  'café',
#  'netherlands',
#  'friday',
#  '16',
#  'april',
#  'door',
#  'online',
#  'language',
#  'café',
#  'open',
#  '16.00',
#  '17.00',
#  'hrs',
#  'read',
#  'um',
#  'psychologists',
#  'loss',
#  'mourning',
#  'sender',
#  'um',
#  'career',
#  'services',
#  'mailto:careerservices@maastrichtuniversity.nl',
#  'loss',
#  'mourning',
#  'online',
#  'meeting',
#  'loss',
#  'mourning',
#  'organise',
#  'student',
#  'lose',
#  'love',
#  'one',
#  'meeting',
#  'get',
#  'support',
#  'start',
#  'continue',
#  'grieving',
#  'process',
#  'small',
#  'group',
#  'student',
#  'try',
#  'find',
#  'way',
#  'cope',
#  'loss',
#  'meet',
#  'connect',
#  'peer',
#  'share',
#  'experience',
#  'information',
#  'registration',
#  'website',
#  'public',
#  'r/9yeysjsqswarvjmmn4tnug',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'edition',
#  'general',
#  'announcement',
#  'please',
#  'allow',
#  'go',
#  'back',
#  'university',
#  'umcard',
#  'payment',
#  'temporarily',
#  'order',
#  'tomorrow',
#  '6:00',
#  'pm',
#  'student',
#  'panel',
#  'lose',
#  'legal',
#  'regulation',
#  'relate',
#  'study',
#  'ask',
#  'student',
#  'dean',
#  'student',
#  'accommodation',
#  'sorbonnelaan',
#  'make',
#  'voice',
#  'hear',
#  'get',
#  'active',
#  'spring',
#  'um',
#  'step',
#  'challenge',
#  'start',
#  'thursday',
#  'subscribe',
#  'observant',
#  'newsletter',
#  'seminar',
#  'symposia',
#  'lecture',
#  'online',
#  'programme',
#  'studium',
#  'generale',
#  'data',
#  'science',
#  'research',
#  'seminar',
#  'series',
#  'maastricht',
#  'young',
#  'academy',
#  'organise',
#  'seventh',
#  'gus',
#  'event',
#  'um',
#  'lecture',
#  'future',
#  'paris',
#  'agreement',
#  'simply',
#  'listen',
#  'professional',
#  'storyteller',
#  'sometimes',
#  'enough',
#  'upcoming',
#  'course',
#  'um',
#  'wellbeing',
#  'movement',
#  'present',
#  'wellbeing',
#  'wednesday',
#  'study',
#  'skills',
#  'discover',
#  'online',
#  'law',
#  'politics',
#  'course',
#  'get',
#  'science',
#  'online',
#  'summer',
#  'course',
#  'join',
#  'online',
#  'language',
#  'cafe',
#  'um',
#  'psychologists',
#  'loss',
#  'mourning',
#  'wijzig',
#  'je',
#  'taalvoorkeur',
#  'public',
#  'qn7opantyikvvli4jst_hq',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'follow',
#  'facebook]<https://mailing.maastrichtuniversity.nl',
#  'public',
#  'suuoxlxyj3mrnlz0ifk2xq',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'twitter',
#  'linkedin',
#  'legal',
#  'right',
#  'derive',
#  'email',
#  'click',
#  'public',
#  'jzuhwrpttgiklnu9zsi2vw',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'want',
#  'change',
#  'preferred',
#  'language',
#  'copyright',
#  '2021',
#  'universiteit',
#  'maastricht',
#  'right',
#  'reserve',
#  'maastricht',
#  'university',
#  'p.o.',
#  'box',
#  '616',
#  '6200',
#  'md',
#  'maastricht',
#  'netherlands',
#  'disclaimer',
#  'public',
#  'rhdiaco+htdidrkkwylmlg',
#  'h5dpxkmlikx7wxchj+z15g/9e_9ijypjoi9bb7nrb0loa',
#  'communicatie@maastrichtuniversity.nl']
